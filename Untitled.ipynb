# %% [markdown]
# ### Linux系统的目录结构
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Linux命令的基本格式
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ls命令
# ![image.png](attachment:image.png)
